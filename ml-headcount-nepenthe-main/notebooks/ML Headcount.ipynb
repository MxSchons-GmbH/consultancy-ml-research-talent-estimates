# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ml_headcount.hamilton_pipeline import HamiltonMLHeadcountPipeline

# %%
pipeline = HamiltonMLHeadcountPipeline()
pipeline.visualize_pipeline(output_path="graph.png")
# Out:
# Failed to visualize pipeline: Unknown nodes [g,
# r,
# a,
# p,
# h,
# .,
# p,
# n,
# g] requested. Check for typos?
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 pipeline = HamiltonMLHeadcountPipeline()
# ----> 2 pipeline.visualize_pipeline(output_path="graph.png")
#
# File ~/work/max-schons/ml-headcount/src/ml_headcount/hamilton_pipeline.py:256, in HamiltonMLHeadcountPipeline.visualize_pipeline(self, output_path)
#     252 try:
#     253     # Use display_all_functions to show the pipeline structure
#     254     if output_path:
#     255         # For file output, we'll use visualize_execution
# --> 256         self.dr.visualize_execution(output_path)
#     257         logger.info(f"Pipeline visualization saved to {output_path}")
#     258     else:
#     259         # For interactive display, use display_all_functions
#
# File ~/work/max-schons/ml-headcount/.venv/lib/python3.9/site-packages/hamilton/driver.py:75, in capture_function_usage.<locals>.wrapped_fn(*args, **kwargs)
#      72 @functools.wraps(call_fn)
#      73 def wrapped_fn(*args, **kwargs):
#      74     try:
# ---> 75         return call_fn(*args, **kwargs)
#      76     finally:
#      77         if telemetry.is_telemetry_enabled():
#
# File ~/work/max-schons/ml-headcount/.venv/lib/python3.9/site-packages/hamilton/driver.py:1088, in Driver.visualize_execution(self, final_vars, output_file_path, render_kwargs, inputs, graphviz_kwargs, overrides, show_legend, orient, hide_inputs, deduplicate_inputs, show_schema, custom_style_function, bypass_validation, keep_dot)
#    1053 """Visualizes Execution.
#    1054
#    1055 Note: overrides are not handled at this time.
#    (...)
#    1085     If returned as the result in a Jupyter Notebook cell, it will render.
#    1086 """
#    1087 _final_vars = self._create_final_vars(final_vars)
# -> 1088 return self._visualize_execution_helper(
#    1089     self.graph,
#    1090     self.adapter,
#    1091     _final_vars,
#    1092     output_file_path,
#    1093     render_kwargs,
#    1094     inputs,
#    1095     graphviz_kwargs,
#    1096     overrides,
#    1097     show_legend=show_legend,
#    1098     orient=orient,
#    1099     hide_inputs=hide_inputs,
#    1100     deduplicate_inputs=deduplicate_inputs,
#    1101     show_schema=show_schema,
#    1102     custom_style_function=custom_style_function,
#    1103     bypass_validation=bypass_validation,
#    1104     keep_dot=keep_dot,
#    1105 )
#
# File ~/work/max-schons/ml-headcount/.venv/lib/python3.9/site-packages/hamilton/driver.py:988, in Driver._visualize_execution_helper(fn_graph, adapter, final_vars, output_file_path, render_kwargs, inputs, graphviz_kwargs, overrides, show_legend, orient, hide_inputs, deduplicate_inputs, show_schema, custom_style_function, bypass_validation, keep_dot)
#     971 """Helper function to visualize execution, using a passed-in function graph.
#     972
#     973 :param final_vars: The final variables to compute.
#    (...)
#     985 :return: the graphviz object if you want to do more with it.
#     986 """
#     987 # TODO should determine if the visualization logic should live here or in the graph.py module
# --> 988 nodes, user_nodes = fn_graph.get_upstream_nodes(final_vars, inputs, overrides)
#     989 if not bypass_validation:
#     990     try:
#
# File ~/work/max-schons/ml-headcount/.venv/lib/python3.9/site-packages/hamilton/graph.py:1010, in FunctionGraph.get_upstream_nodes(self, final_vars, runtime_inputs, runtime_overrides)
#    1007         deps.append(dep)
#    1008     return deps
# -> 1010 return self.directional_dfs_traverse(
#    1011     next_nodes_function, starting_nodes=final_vars, runtime_inputs=runtime_inputs
#    1012 )
#
# File ~/work/max-schons/ml-headcount/.venv/lib/python3.9/site-packages/hamilton/graph.py:1073, in FunctionGraph.directional_dfs_traverse(self, next_nodes_fn, starting_nodes, runtime_inputs)
#    1071 if missing_vars:
#    1072     missing_vars_str = ",\n".join(missing_vars)
# -> 1073     raise ValueError(f"Unknown nodes [{missing_vars_str}] requested. Check for typos?")
#    1074 return nodes, user_nodes
#
# ValueError: Unknown nodes [g,
# r,
# a,
# p,
# h,
# .,
# p,
# n,
# g] requested. Check for typos?
